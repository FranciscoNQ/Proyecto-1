# %% [markdown]
# ## **Fuentes**

# %% [markdown]
# Datos obtenidos de fuentes oficiales del Gobierno de la República Argentina.
# - (https://www.indec.gob.ar/)
# - (https://datos.gob.ar/)

# %% [markdown]
# # **Introduccion**
#
# En este informe se analizan las variaciones porcentuales del salario mínimo frente al dólar oficial y la inflación  desde el 1 de enero del 2017 hasta la actualidad (Tener encuenta que los datos de inflacion tardan mas en publicarse que los demas). El objetivo es mostrar cómo el salario mínimo fue perdiendo poder adquisitivo con el tiempo, tanto a nivel local (por la inflación) como a nivel internacional (frente al dólar estadounidense).
#
# En otras palabras, se mostrara cómo el salario mínimo se fue licuando con el tiempo.

# %% [markdown]
# ## Modulo Funciones

# %%
# %run permite ejecutar otro archivo ubicado en otra ruta, directamente desde una celda.
# Esto sirve para mantener el código separado, más ordenado, y hacer que el informe sea visualmente más facil de leer.
# %run "/content/drive/MyDrive/Proyecto #1/Funciones.ipynb"

#Traemos las funciones
df = dataframe()
df, ultima_fecha, cantidad_de_filas = variable_fecha_reciente(df)
diferencia_salario_x_dolar, diferencia_salario_x_inflacion, salario, inflacion, dolar = variables_calculos_diferencias_salario(df, cantidad_de_filas)
diferencia_dolar = variable_calculo_diferencia_dolar(inflacion, dolar)
grafico_dolar, grafico_salario, grafico_inflacion = variables_graficos(df, ultima_fecha)

# %% [markdown]
# ## Variación mensual (%): Salario mínimo, dólar oficial y  inflación.

# %%
salario_minimo_grafico(df, grafico_salario)
# Out:
# Salario Minimo:
# * El valor promedio mensual es de 3.87 %.
# * El valor mas alto en la variacion mensual es de 19.9 %, que fue en la fecha 2023-07-01.
# * El valor más bajo en la variación mensual es de 0.0 %, y se repite en varias fechas. Sí, hubo muchos meses en los que el salario no tuvo ningún aumento.

# %%
dolar_grafico(df, grafico_dolar)
# Out:
# Dólar Oficial:
# * El valor promedio mensual es de 4.91 %.
# * El valor mas alto en la variacion mensual es de 129.37 %, que fue en la fecha 2024-01-01.
# * El valor mas bajo en la variacion mensual es de -9.81 %, que fue en la fecha 2018-11-01.

# %%
inflacion_grafico(df, grafico_inflacion)
# Out:
# Inflación:
# * El valor promedio mensual es de 4.61 %.
# * El valor mas alto en la variacion mensual es de 25.5 %, que fue en la fecha 2023-12-01.
# * El valor mas bajo en la variacion mensual es de 1.2 %, que fue en la fecha 2017-06-01.

# %% [markdown]
# ## **Conclusión**

# %%
grafico_acumulado(df, ultima_fecha, salario, dolar, inflacion)
# Out:
# Ultima actualizacion: 2025-04-01
# * Salario acumulado: 4002.65 %
# * Inflacion acumulada: 8585.6078 %
# * Dolar acumulado: 6817.76 %

# %%
conclusion(diferencia_salario_x_inflacion, diferencia_salario_x_dolar, ultima_fecha, diferencia_dolar)
# Out:
# El salario mínimo creció un 114.5 % menos que la inflación y un 70.33 % menos que el dólar oficial en el mismo período (2017-01-01 a 2025-04-01).
# Esto demuestra la gran pérdida de poder adquisitivo frente a ambos indicadores, con una diferencia abismal.
# Si observamos el gráfico anterior de acumulación, el salario mínimo nunca repuntó ni estuvo cerca de la inflación ni del dólar.
# ¿Qué significa esto? Se podría interpretar de diferentes maneras:
#
# * "Los gobiernos priorizaron otros factores macroeconómicos (guiño) menos el más importante."
# * "Todos saben, todos son expertos en economía, pero cuando toman el puesto, demuestran lo contrario."
# * "La culpa es de otro."
#
# También se puede observar que hay una diferencia del 25.93 % entre el dólar oficial y la inflación.
# Generalmente, el dólar suele acompañar el movimiento de los precios, por lo que esta brecha podría indicar que el tipo de cambio oficial se encuentra atrasado respecto al ritmo inflacionario.
# ...

# %% [markdown]
# ## **Aclaración:**

# %% [markdown]
# - La conclusión del informe no esta automatizada (25/03/25).
# - Los datos y gráficos se actualizan automáticamente. Por lo general, se actualizan a mediados de cada mes.

# %% [markdown]
# ## **Dashboard interactivo**

# %% [markdown]
# En el siguiente enlace podra visualizar y interactuar con los graficos en:
# [LookerStudio](https://lookerstudio.google.com/s/nNJZK8X0Nok)
